# %%
from ghostnetmodel4 import ghost_net
import torch
model=ghost_net()

# %%
model.eval()
# Out:
# GhostNet(
#   (features): Sequential(
#     (0): Sequential(
#       (0): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#     (1): GhostBottleneck(
#       (conv): Sequential(
#         (0): GhostModule(
#           (primary_conv): Sequential(
#             (0): Conv2d(16, 8, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#           )
#           (cheap_operation): Sequential(
#             (0): Conv2d(8, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=8, bias=False)
#             (1): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#           )
#         )
#         (1): Sequential()
# ...

# %%
import keras
model=keras.models.load_model('GN_W0.5_S2_ArcFace_epoch16.h5')
# Out:
# INFO:tensorflow:Mixed precision compatibility check (mixed_float16): OK
# Your GPU will likely run quickly with dtype policy mixed_float16 as it has compute capability of at least 7.0. Your GPU: NVIDIA GeForce RTX 3050 Laptop GPU, compute capability 8.6
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
model.summary()
# Out:
# Model: "GhostNet"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_2 (InputLayer)           [(None, 112, 112, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 56, 56, 8)    216         ['input_2[0][0]']
#
#  batch_normalization (BatchNorm  (None, 56, 56, 8)   32          ['conv2d[0][0]']
#  alization)
#
#  activation (PReLU)             (None, 56, 56, 8)    8           ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 56, 56, 4)    32          ['activation[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 56, 56, 4)   16          ['conv2d_1[0][0]']
#  rmalization)
#
#  activation_1 (PReLU)           (None, 56, 56, 4)    4           ['batch_normalization_1[0][0]']
#
#  depthwise_conv2d (DepthwiseCon  (None, 56, 56, 4)   36          ['activation_1[0][0]']
#  v2D)
#
# ...

# %%
# %pip install mmdnn
# Out:
# ...
#   Using cached mmdnn-0.3.1-py2.py3-none-any.whl (318 kB)
# ...
#      ---------------------------------------- 2.6/2.6 MB 652.3 kB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchvision 0.15.2 requires torch==2.0.1, which is not installed.

# %%
# %pip install torch==2.0.1
# Out:
# ...
#   Using cached torch-2.0.1-cp39-cp39-win_amd64.whl (172.4 MB)
# ...
#   Using cached sympy-1.12-py3-none-any.whl (5.7 MB)
# ...
#      ---------------------------------------- 1.6/1.6 MB 3.7 MB/s eta 0:00:00
# ...
#   Using cached Jinja2-3.1.2-py3-none-any.whl (133 kB)
# ...
#   Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install torchvision==0.15.2
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %mmconvert -sf keras -iw GN_W0.5_S2_ArcFace_epoch16.h5 -df pytorch -om keras_to_torch.pt
# Out:
# UsageError: Line magic function `%mmconvert` not found.
